# %%
# Let's solve the new set of assignment questions one by one:

# ### Q1. How do you comment code in Python? What are the different types of comments?

# In Python, you can use comments to describe your code and make it more readable. There are two types of comments:
# 1. **Single-line comments**: Use the `#` symbol to start a comment.
# 2. **Multi-line comments**: Use triple quotes (`'''` or `"""`) to create a comment block that spans multiple lines.

# ```python
# # This is a single-line comment

# '''
# This is a multi-line comment
# which spans across multiple lines
# '''

# """
# This is another way to write
# a multi-line comment
# """
# ```

# ### Q2. What are variables in Python? How do you declare and assign values to variables?

# Variables in Python are used to store data that can be manipulated and referenced in a program. You declare and assign values to variables by using the assignment operator `=`.

# ```python
# # Declaring and assigning values to variables
# x = 10
# y = 20.5
# name = "John"
# is_student = True
# ```

# ### Q3. How do you convert one data type to another in Python?

# You can convert one data type to another using type conversion functions like `int()`, `float()`, `str()`, `list()`, `tuple()`, etc.

# ```python
# # Converting data types
# a = 5
# b = float(a)  # int to float
# c = str(a)    # int to string
# d = int(c)    # string to int
# ```

# ### Q4. How do you write and execute a Python script from the command line?

# To write and execute a Python script from the command line, follow these steps:
# 1. Create a Python script file with a `.py` extension, e.g., `script.py`.
# 2. Write your Python code in the script file.
# 3. Open the command line interface.
# 4. Navigate to the directory where your script is located.
# 5. Execute the script by typing `python script.py` (or `python3 script.py` if you are using Python 3).

# ```python
# # Example Python script (script.py)
# print("Hello, World!")
# ```

# ### Q5. Given a list `my_list = [1, 2, 3, 4, 5]`, write the code to slice the list and obtain the sub-list `[2, 3]`.

# ```python
# my_list = [1, 2, 3, 4, 5]
# sub_list = my_list[1:3]
# print(sub_list)  # Output: [2, 3]
# ```

# ### Q6. What is a complex number in mathematics, and how is it represented in Python?

# A complex number is a number that has both a real part and an imaginary part. It is represented in Python using the `complex` class. The imaginary part is denoted by the letter `j`.

# ```python
# # Representing a complex number
# z = 3 + 4j
# print(z)            # Output: (3+4j)
# print(z.real)       # Output: 3.0
# print(z.imag)       # Output: 4.0
# ```

# ### Q7. What is the correct way to declare a variable named `age` and assign the value 25 to it?

# ```python
# age = 25
# print(age)  # Output: 25
# ```

# ### Q8. Declare a variable named `price` and assign the value 9.99 to it. What data type does this variable belong to?

# ```python
# price = 9.99
# print(type(price))  # Output: <class 'float'>
# ```

# ### Q9. Create a variable named `name` and assign your full name to it as a string. How would you print the value of this variable?

# ```python
# name = "Your Full Name"
# print(name)
# ```

# ### Q10. Given the string "Hello, World!", extract the substring "World".

# ```python
# string = "Hello, World!"
# substring = string[7:12]
# print(substring)  # Output: World
# ```

# ### Q11. Create a variable named "is_student" and assign it a boolean value indicating whether you are currently a student or not.

# ```python
# is_student = True  # or False, depending on your status
# print(is_student)
# ```

# These solutions should cover all the assignment questions. Let me know if you need any further assistance!
